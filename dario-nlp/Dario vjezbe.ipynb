# %%
import json
import pandas as pd
import re
import spacy
import numpy as np

# %%
def read_food_json(filepath):
    with open(filepath) as f:
        data = json.loads(f.read())

    texts = []
    foods = []
    labels = []
    for conversation in data:
        utterances = conversation['utterances']
        for utterance in utterances:
            text = utterance['text']
            texts.append(text) # ok

            try:
                fs = []
                anns = []
                for segment in utterance['segments']:
                    food_words = segment['text']
                    fs.append(food_words)
                    annotations = segment['annotations']
                    for annotation in annotations:
                        anns.append(annotation['name'])
                foods.append(fs)
                labels.append(anns)
            except KeyError:
                foods.append([])
                labels.append([])
                continue

    assert len(texts) == len(foods) == len(labels)
    return texts, foods, labels

# %%
food_ordering_file = "food-ordering.json"
restauraunt_search_file = "restaurant-search.json"
food_ordering_texts, food_ordering_foods, food_ordering_labels = read_food_json(food_ordering_file)
restauraunt_search_texts, restauraunt_search_foods, restauraunt_search_labels = read_food_json(restauraunt_search_file)
texts = food_ordering_texts + restauraunt_search_texts
foods = food_ordering_foods + restauraunt_search_foods
labels = food_ordering_labels + restauraunt_search_labels
assert len(texts) == len(foods) == len(labels)

# %%
df = pd.DataFrame(list(zip(texts, foods, labels)), columns=["Utterances", "Segments", "Annotations"])

# %%
df.head(20)
# Out:
#                                            Utterances  \
# 0                                                 Hi.
# 1                                 How can I help you?
# 2           What would you like to order in Barbecue?
# 3               Yeah, I'd like to get a rack of ribs.
# 4             What kind of sides can I get with that?
# 5   With rack of ribs, I would suggest Barbecue sa...
# 6   Yeah. Of course, I want the barbecue sauce and...
# 7                        Would you like to add extra?
# 8   No, I'd like to get a salad with that. No toma...
# 9   Salad with no tomatoes and ranch dressing has ...
# 10  Is there anything else you would like to add l...
# 11                Can I get a potato, a baked potato?
# 12     A Diet Coke or Pepsi, whichever one they have.
# 13  Baked potato and diet coke has been added to t...
# 14                                 That sounds great.
# 15      Is there anything else you would like to add?
# 16          No, I think that'll do it for me. Thanks.
# 17  Okay, I have your personal details on file, yo...
# 18                                         Thank you.
# 19                                    You're welcome.
#
#                                              Segments  \
# 0                                                  []
# 1                                                  []
# 2                                          [Barbecue]
# 3                                    [a rack of ribs]
# 4                                                  []
# 5                 [With rack of ribs, Barbecue sauce]
# 6   [barbecue sauce, ribs, slaw or macaroni and ch...
# 7                                                  []
# 8         [No tomatoes, with ranch dressing, a salad]
# 9        [Salad, with no tomatoes and ranch dressing]
# 10                                    [fries, drinks]
# 11                             [potato, baked potato]
# 12                               [A Diet Coke, Pepsi]
# 13                          [Baked potato, diet coke]
# 14                                                 []
# 15                                                 []
# 16                                                 []
# 17                                       [20 minutes]
# 18                                                 []
# 19                                                 []
#
#                                           Annotations
# 0                                                  []
# 1                                                  []
# 2                              [food_order.type.food]
# 3                              [food_order.name.item]
# 4                                                  []
# 5        [food_order.name.item, food_order.name.item]
# 6   [food_order.name.item, food_order.name.item, f...
# 7                                                  []
# 8   [food_order.other_description.item, food_order...
# 9   [food_order.name.item, food_order.other_descri...
# 10       [food_order.type.food, food_order.type.food]
# 11       [food_order.name.item, food_order.name.item]
# 12       [food_order.name.item, food_order.name.item]
# 13       [food_order.name.item, food_order.name.item]
# 14                                                 []
# 15                                                 []
# 16                                                 []
# 17                           [food_order.time.pickup]
# 18                                                 []
# 19                                                 []

# %%
df.tail(20)
# Out:
#                                               Utterances  \
# 80138         Okay, I found a few places you might like.
# 80139  How about Spinners Pizza or Kings Subs and Piz...
# 80140  I'll go with House of Pizza, can you tell me w...
# 80141   It is located at 53 Essex St, Andover, MA 01810.
# 80142               Thank you, I'll head over there now.
# 80143                                    You're welcome.
# 80144                                        I'm hungry.
# 80145                            Hi, how can I help you?
# 80146  Sure I can help. Any particular food you are l...
# 80147  I really like American food. I wonder if there...
# 80148                             Ok sure, let me check.
# 80149                                      Okay, thanks.
# 80150  I found the Burgers and Brews restaurant. Know...
# 80151              That's perfect. They have a bar, too?
# 80152                                      Yes, they do.
# 80153                  How many stars is the restaurant?
# 80154                                         4.4 stars.
# 80155  Oh, that's perfect. I'd love to dine there. Th...
# 80156        You're welcome. Talk to you next time. Bye.
# 80157                         Have a great day. Bye bye.
#
#                                                 Segments  \
# 80138                                                 []
# 80139  [Spinners Pizza, Kings Subs and Pizza, Depot H...
# 80140                                   [House of Pizza]
# 80141                   [53 Essex St, Andover, MA 01810]
# 80142                                                 []
# 80143                                                 []
# 80144                                                 []
# 80145                                                 []
# 80146                                                 []
# 80147                                 [American, burger]
# 80148                                                 []
# 80149                                                 []
# 80150  [Burgers and Brews restaurant, Spicy Avocado B...
# 80151                                            [a bar]
# 80152                                                 []
# 80153                                                 []
# 80154                                        [4.4 stars]
# 80155                                                 []
# 80156                                                 []
# 80157                                                 []
#
#                                              Annotations
# 80138                                                 []
# 80139  [restaurant.name.restaurant, restaurant.name.r...
# 80140                       [restaurant.name.restaurant]
# 80141                              [restaurant.location]
# 80142                                                 []
# 80143                                                 []
# 80144                                                 []
# 80145                                                 []
# 80146                                                 []
# 80147       [restaurant.type.food, restaurant.type.food]
# 80148                                                 []
# 80149                                                 []
# 80150  [restaurant.name.restaurant, restaurant.menu_i...
# 80151                     [restaurant.other_description]
# 80152                                                 []
# 80153                                                 []
# 80154                                [restaurant.rating]
# 80155                                                 []
# 80156                                                 []
# 80157                                                 []

# %%
df_foods = pd.read_csv("food_related.csv", names=["foods"])

# %%
df_foods.head(20)
# Out:
#                          foods
# 0                      a-yeast
# 1                          aai
# 2                      abalone
# 3                    abba-zaba
# 4                abbreviations
# 5                     abietate
# 6                        above
# 7                     absorbed
# 8                    absorbent
# 9                     absorbic
# 10                         abv
# 11                  abyssinica
# 12                          ac
# 13                      acacia
# 14               acacianatural
# 15                        acai
# 16  acai-blueberry-pomegranate
# 17                       acaia
# 18                  accesflame
# 19                      access

# %%
nlp = spacy.load("en_core_web_lg")

# %%
labels = []

for text in df["Utterances"]:
    tmp = []
    doc = nlp(text)
    for token in doc:
        if token.text in df_foods["foods"].values:
            tmp.append(1)
        else:
            tmp.append(0)
    labels.append(tmp)

# %%
len(labels)
# Out:
# 80158

# %%
max_length = 0
for label in labels:
    if len(label) > max_length:
        max_length = len(label)

# %%
max_length
# Out:
# 158

# %%
labels_padded = []

for label in labels:
    if len(label) < max_length:
        labels_padded.append(label + ([2] * (max_length - len(label))))
    else:
        labels_padded.append(label)

# %%
len(labels_padded)
# Out:
# 80158

# %%
def get_placeholder_vector(d):
    return np.ones(d)

# %%
def spacy_parser(nlp, text):
    # https://spacy.io/api/doc
    doc = nlp(text)
    tokens = []
    vectors = []
    # https://spacy.io/usage/linguistic-features#sbd
    for token in doc:
        # https://spacy.io/api/token
        # https://spacy.io/usage/linguistic-features#lemmatization
        # https://spacy.io/api/lemmatizer
        # https://spacy.io/usage/linguistic-features#vectors-similarity

        # print(token.text, token.has_vector, token.vector_norm, token.is_oov)
        if token.has_vector:
            vector = token.vector
        else:
            vector = get_placeholder_vector(300) # ((300,1) is the shape of the vector in Spacy)

        tokens.append(token.text)
        vectors.append(vector)
    # print("tokens with no vectors:", no_vector)
    # if there is a very low count of vectors: https://spacy.io/usage/linguistic-features#adding-vectors 
    return tokens, vectors

# %%
tokens = []
embedings = []

for idx, row in df.iterrows():
    t, e = spacy_parser(nlp, row["Utterances"])
    tokens.append(t)
    embedings.append(e)

# %%
len(embedings)
# Out:
# 80158

# %%
len(embedings[0][0])
# Out:
# 300

# %%
embeding_size = 300

# %%
padded_embedings = []

for embeding in embedings:
    tmp = []
    embeding_len = len(embeding)
    if embeding_len < max_length:
        for _ in range(max_length - embeding_len):
            tmp.append([0] * embeding_size)
        padded_embedings.append(np.concatenate((embeding, tmp), axis=0))
    else:
        padded_embedings.append(embeding)

# %%
len(padded_embedings)

# %%
X = np.array(padded_embedings)

# %%
X.shape
